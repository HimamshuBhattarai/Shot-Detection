# %%
import cv2
import random
import matplotlib.pyplot as plt
from ultralytics import YOLO
import mediapipe as mp

# %%
model = YOLO('yolov8n.pt')

# %%
cap = cv2.VideoCapture("D:\Dev\cv task\input.mp4")

# %% [markdown]
# ## Inspection of the video

# %%
fps    = cap.get(cv2.CAP_PROP_FPS)
frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
print("FPS:",fps)
# Out:
# FPS: 25.0

# %%
print("Total frames:", frames)
# Out:
# Total frames: 8125

# %%
print("Width x Height:", width, height)
# Out:
# Width x Height: 1920 1080

# %% [markdown]
# ## Displaying the Frames

# %%
def get_frame(cap, frame_no):
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_no)
    ret, frame = cap.read()
    if ret:
        return cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    return None

# %%
random_frames = random.sample(range(frames), 6)


fig, axes = plt.subplots(2, 3, figsize=(18, 8))
for ax, fn in zip(axes.flatten(), random_frames):
    frame = get_frame(cap, fn)
    ax.imshow(frame)
    ax.set_title(f"Frame {fn}")
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Checking what YOLO finds on a single frame

# %%
test_frame = get_frame(cap, frames // 2)  # middle of video
results = model(test_frame, verbose=False)[0]

# %%
for box in results.boxes:
    cls_id  = int(box.cls)
    cls_name = model.names[cls_id]
    conf    = float(box.conf)
    print(f"Detected: {cls_name:20s} confidence: {conf:.2f}")
# Out:
# Detected: person               confidence: 0.52
# Detected: person               confidence: 0.29
# Detected: person               confidence: 0.27

# %%
annotated = results.plot()
plt.figure(figsize=(12, 7))
plt.imshow(annotated)
plt.title("YOLO Detections")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Frequency of Ball

# %%
def detect_ball(frame):
    hsv = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)
    
    # yellow-green range for padel ball
    lower = np.array([25, 50, 50])
    upper = np.array([65, 255, 255])
    
    mask = cv2.inRange(hsv, lower, upper)
    
    # find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    ball_candidates = []
    for cnt in contours:
        area = cv2.contourArea(cnt)
        if 10 < area < 500:  # ball is small
            (x, y), radius = cv2.minEnclosingCircle(cnt)
            ball_candidates.append((int(x), int(y), radius, area))
    
    return ball_candidates

# %%
# ── BALL DETECTION TEST ─────────────────────────────────────
test_frame = get_frame(cap, frames // 2)

balls = detect_ball(test_frame)
print(f"Ball candidates found: {len(balls)}")
for b in balls:
    print(f"  x:{b[0]} y:{b[1]} radius:{b[2]:.1f} area:{b[3]:.1f}")

# visualize
vis = test_frame.copy()
for (x, y, r, area) in balls:
    cv2.circle(vis, (x, y), int(r), (255, 0, 0), 2)

plt.figure(figsize=(12, 7))
plt.imshow(vis)
plt.title(f"Ball Candidates: {len(balls)}")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[21], line 4
#       1 # ── BALL DETECTION TEST ─────────────────────────────────────
#       2 test_frame = get_frame(cap, frames // 2)
#       3
# ----> 4 balls = detect_ball(test_frame)
#       5 print(f"Ball candidates found: {len(balls)}")
#       6 for b in balls:
#       7     print(f"  x:{b[0]} y:{b[1]} radius:{b[2]:.1f} area:{b[3]:.1f}")
#
# Cell In[18], line 2, in detect_ball(frame)
#       1 def detect_ball(frame):
# ----> 2     hsv = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)
#       3
#       4     # yellow-green range for padel ball
#       5     lower = np.array([25, 50, 50])
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ## Running Mediapipe on one player crop

# %%
print(mp.__version__)
# Out:
# 0.10.9

# %%
mp_pose    = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose       = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# grab a frame and get first person bounding box from YOLO
test_frame = get_frame(cap, frames // 2)
results    = model(test_frame, verbose=False)[0]

player_crop = None

# %%
for box in results.boxes:
    if model.names[int(box.cls)] == 'person':
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        # add some padding
        pad = 20
        x1, y1 = max(0, x1-pad), max(0, y1-pad)
        x2, y2 = min(width, x2+pad), min(height, y2+pad)
        player_crop = test_frame[y1:y2, x1:x2]
        break

if player_crop is not None:
    pose_results = pose.process(player_crop)
    
    annotated_crop = player_crop.copy()
    if pose_results.pose_landmarks:
        mp_drawing.draw_landmarks(
            annotated_crop,
            pose_results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS
        )
        print("Pose landmarks detected successfully!")
        
        # print key joint positions
        lm = pose_results.pose_landmarks.landmark
        print(f"Right wrist  — x:{lm[mp_pose.PoseLandmark.RIGHT_WRIST].x:.2f}  y:{lm[mp_pose.PoseLandmark.RIGHT_WRIST].y:.2f}")
        print(f"Right elbow  — x:{lm[mp_pose.PoseLandmark.RIGHT_ELBOW].x:.2f}  y:{lm[mp_pose.PoseLandmark.RIGHT_ELBOW].y:.2f}")
        print(f"Right shoulder — x:{lm[mp_pose.PoseLandmark.RIGHT_SHOULDER].x:.2f}  y:{lm[mp_pose.PoseLandmark.RIGHT_SHOULDER].y:.2f}")
    else:
        print("❌ No pose landmarks found on this crop — try a different frame")
    
    plt.figure(figsize=(6, 8))
    plt.imshow(annotated_crop)
    plt.title("MediaPipe Pose on Player Crop")
    plt.axis('off')
    plt.show()
else:
    print("No person detected in this frame — try a different frame number")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 8
#       4         # add some padding
#       5         pad = 20
#       6         x1, y1 = max(0, x1-pad), max(0, y1-pad)
#       7         x2, y2 = min(width, x2+pad), min(height, y2+pad)
# ----> 8         player_crop = test_frame[y1:y2, x1:x2]
#       9         break
#      10
#      11 if player_crop is not None:
#
# TypeError: 'NoneType' object is not subscriptable
